# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create dataset
data = {
    "Name": ["Aman", "Riya", "Rahul", "Priya", "Neha"],
    "Marks": [80, 75, 90, 85, 70]
}

df = pd.DataFrame(data)

# Show data
print("Student Data:\n", df)

# Basic analysis
print("\nAverage Marks:", df["Marks"].mean())
print("Highest Marks:", df["Marks"].max())

# Visualization
plt.bar(df["Name"], df["Marks"])
plt.title("Student Marks Analysis")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()
# Out:
# Student Data:
#      Name  Marks
# 0   Aman     80
# 1   Riya     75
# 2  Rahul     90
# 3  Priya     85
# 4   Neha     70
#
# Average Marks: 80.0
# Highest Marks: 90

# %% [markdown]
# # Student Marks Analysis Project
#
# ## Objective:
# To analyze student marks using Python.
#
# ## Tools Used:
# - Python
# - Pandas
# - Matplotlib
